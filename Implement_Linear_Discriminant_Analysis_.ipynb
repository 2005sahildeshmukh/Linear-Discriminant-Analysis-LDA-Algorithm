# %% [markdown]
# # Task
# Implement Linear Discriminant Analysis step by step, compare the results with PCA and t-SNE, and visualize the results.

# %% [markdown]
# ## Apply lda
#
# ### Subtask:
# Apply Linear Discriminant Analysis (LDA) to reduce dimensionality.

# %% [markdown]
# **Reasoning**:
# Apply Linear Discriminant Analysis to reduce dimensionality and store the results in a DataFrame.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=2)
lda_transformed = lda.fit_transform(features, labels)
lda_df = pd.DataFrame(data=lda_transformed, columns=['LDA_1', 'LDA_2'])
lda_df['label'] = labels
display(lda_df.head())
# Out:
#       LDA_1     LDA_2  label
# 0  0.044495 -0.345688      5
# 1  1.088690 -2.677992      7
# 2  2.265079 -1.869145      9
# 3 -0.268947 -0.528287      5
# 4 -1.121820  0.616736      2

# %% [markdown]
# ## Visualize lda results
#
# ### Subtask:
# Visualize the results of LDA.

# %% [markdown]
# **Reasoning**:
# Create a scatter plot of the LDA-transformed data, coloring points by label and adding appropriate titles and labels.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.scatterplot(x='LDA_1', y='LDA_2', hue='label', data=lda_df, palette='viridis')
plt.title('LDA of Digits Dataset')
plt.xlabel('LDA Component 1')
plt.ylabel('LDA Component 2')
plt.legend(title='Digit')
plt.show()

# %% [markdown]
# ## Compare lda with pca and t-sne
#
# ### Subtask:
# Compare the results of LDA with PCA and t-SNE.

# %% [markdown]
# **Reasoning**:
# Create a figure with three subplots and generate scatter plots for PCA, t-SNE, and LDA results, coloring the points by their labels, then add titles and adjust the layout.

# %%
fig, axes = plt.subplots(1, 3, figsize=(24, 8))

sns.scatterplot(ax=axes[0], x='PCA_1', y='PCA_2', hue='label', data=pca_df, palette='viridis', legend=False)
axes[0].set_title('PCA')

sns.scatterplot(ax=axes[1], x='TSNE_1', y='TSNE_2', hue='label', data=tsne_df, palette='viridis', legend=False)
axes[1].set_title('t-SNE')

sns.scatterplot(ax=axes[2], x='LDA_1', y='LDA_2', hue='label', data=lda_df, palette='viridis')
axes[2].set_title('LDA')

fig.suptitle('Comparison of Dimensionality Reduction Techniques', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   LDA successfully reduced the dimensionality of the dataset to 2 components.
# *   The visualization of the LDA-transformed data shows clear separation between most of the different digit classes in the 2D space.
# *   Comparing the visualizations, LDA appears to provide better class separation than PCA for this dataset.
# *   t-SNE also shows good class separation, potentially capturing non-linear relationships better than LDA or PCA, although the relative positions between clusters might be less meaningful in t-SNE compared to LDA or PCA.
